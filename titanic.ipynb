# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cruise=pd.read_csv('train.csv')

# %%
cruise.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
cruise.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.boxplot(x='Pclass',y='Age',data=cruise)

# %%
plt.pie((cruise.Sex.value_counts()/len(cruise.Sex)) , labels=['Male','Female'] , autopct='%1.1f%%' , colors=['green','orange'])
plt.show()

# %% [markdown]
# Seems like there were much more male passengers than female on Titanic

# %% [markdown]
# # From which dock most passenger were embarked?

# %%
plt.pie((cruise.Embarked.value_counts()/len(cruise.Embarked)) , labels=['Southampton','Cherbourg','Queenstown'] , autopct='%1.1f%%' , colors=['red','cyan','magenta'])
plt.show()

# %% [markdown]
# The most number of passenger were embarked from Southampton and least from Queenstown

# %% [markdown]
# # Who survived and who did not?

# %%
sns.set()
sns.countplot(x='Survived',data=cruise)

# %% [markdown]
# We can conclude from the above plot that over 500 people died on that fateful day.

# %%
sns.set()
sns.countplot(x='Survived',hue='Pclass',data=cruise)

# %% [markdown]
# So from above we can conclude that if you are poor in a cruise which has crashed you are going to die.
# 0 stands for dead
# 1 stands for survive

# %%
sns.countplot(x='Survived',hue='Sex',data=cruise,palette='rainbow')

# %% [markdown]
# So women were allowed to escape first.

# %%
sns.countplot(x='Embarked', hue='Survived', data=cruise, palette = 'rainbow')

# %%
sns.catplot(x='Survived',y='Age',hue='Pclass',data=cruise,kind='violin')

# %% [markdown]
# From the above plot we may conclude that the age group of 20-40 survived more.

# %%
sns.swarmplot(x='Pclass', y='Age', data=cruise)
# Out:
# c:\users\manish\appdata\local\programs\python\python37\lib\site-packages\seaborn\categorical.py:1311: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# c:\users\manish\appdata\local\programs\python\python37\lib\site-packages\seaborn\categorical.py:1315: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %% [markdown]
# From the above beeswarm plot we can infer that the most pasangers were between the age range of 20-40

# %%
max(cruise['Fare'])
# Out:
# 512.3292

# %% [markdown]
# The maximum fare for the titanic was 512.3292 $

# %%
min(cruise['Fare'])
# Out:
# 0.0

# %% [markdown]
# The minimum was 0.0 $

# %%
cruise[['Fare']].mean().round(2)
# Out:
# Fare    32.2
# dtype: float64

# %% [markdown]
# The average fare for a ticket to titanic was 32.20$
